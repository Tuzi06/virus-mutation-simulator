# %%
from Bio import SeqIO,Seq
bank = []
virus = Seq.MutableSeq(SeqIO.read('data/sars.fna', 'fasta').seq)

protein = virus.translate()

str(protein)

# %%
import random
a = 0
b = 0
for i in range(10000):
    a += 1
    if i%2 == 0:
        b += 1
    print(1-b/random.randint(a,a*2))

# %%
'a' in ['adfasf','adfasd','a']
# Out:
# True

# %%
import random
random.random()
# Out:
# 0.4642968569621122
