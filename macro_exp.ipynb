# %%
from Bio import SeqIO,Seq
bank = []
virus = Seq.MutableSeq(SeqIO.read('data/sars.fna', 'fasta').seq)

protein = virus.translate()

str(protein)

# %%
import random
a = 0
b = 0
for i in range(10000):
    a += 1
    if i%2 == 0:
        b += 1
    print(1-b/random.randint(a,a*2))

# %%
import pandas as pd
from pyparsing import col
df = pd.DataFrame({'id':[1,2,4,5,6],'adsaf':[11,23,2324,123,1213]})
df['aaa'] = ['a','b','c','d','e']
df['aaa'].rank()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# Name: aaa, dtype: float64
