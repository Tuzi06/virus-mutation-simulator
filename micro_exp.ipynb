# %%
import copy
import random
from copy import deepcopy
from Bio.Data import CodonTable

def point_mutation(seq):
    base = ['A', 'U', 'C', 'G']
    pos = random.sample(range(0, len(seq)), random.randint(1, 30))
    for i in pos:
        seq[i] = random.choice(base)
    return seq

def indels(seq):
    def ts()
    return seq

def recombination(seq):
    return seq

def Reassortment(seq):
    return seq

def mutation(seq):
    mutation_type = random.choice([point_mutation, indels, recombination, Reassortment])
    return mutation_type(seq)

# %%
from Bio import SeqIO,Seq
bank = []
original_virus = Seq.MutableSeq(SeqIO.read('data/sars.fna', 'fasta').seq)
mutated_seq = copy.deepcopy(original_virus)

# for i in range(100000):
#     mutated_seq = mutation(mutated_seq)

from Bio import Blast
Blast.email = 'damienwang21@gmail.com'

import ssl

ssl._create_default_https_context = ssl._create_unverified_context

result_handle = Blast.qblast("blastn", "nt", mutated_seq)
with open("my_blast.xml", "wb") as out_handle:
    out_handle.write(result_handle.read())

# %%
from Bio import SeqIO,Seq
bank = []
virus = Seq.MutableSeq(SeqIO.read('data/sars.fna', 'fasta').seq)

for i in range(len(virus)):
